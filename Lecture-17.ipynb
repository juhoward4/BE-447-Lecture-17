# %% [markdown]
# # Lecture 17
#
#
# ### Plan:
# 1. Set up imports
# 2. Load Data
# 3. Use standard scaler
# 4. Run PCA/LDA/t-SNE
# 5. Make plots of each output

# %%
#set up imports
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.manifold import TSNE

# %%
# load data
rhodo_df = pd.read_csv('rhodo_data.csv')

print(rhodo_df.shape)

rhodo_df
# Out:
# (18, 87)
#        sample  ...  Unknown - Carbohydrate 002
# 0        SG_1  ...               178790.735700
# 1        SG_2  ...                61108.725740
# 2        SG_3  ...                70565.038360
# 3       GLC_1  ...                93378.791060
# 4       GLC_2  ...                94526.402150
# 5       GLC_3  ...                22869.021230
# 6       PHE_1  ...                42814.000000
# 7       PHE_2  ...                39200.659430
# 8       PHE_3  ...                 1790.613584
# 9   GLC/PHE_1  ...                87521.044140
# 10  GLC/PHE_2  ...                48785.620480
# 11  GLC/PHE_3  ...                77129.954730
# 12    AMIX_1b  ...               136583.487700
# 13    AMIX_2b  ...               229287.650500
# 14    AMIX_3b  ...                94200.171560
# 15    AMIX_1a  ...                86825.617460
# 16    AMIX_2a  ...               141179.016200
# 17    AMIX_3a  ...                79667.855460
#
# [18 rows x 87 columns]

# %%
#preprocess the data
labels = rhodo_df['sample']

# remove labels from df
rhodo_df = rhodo_df.drop('sample', axis=1)

#standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(rhodo_df)

scaled_data

rhodo_df
# Out:
#     2-aminoadipic acid  ...  Unknown - Carbohydrate 002
# 0         3.615204e+05  ...               178790.735700
# 1         2.273096e+05  ...                61108.725740
# 2         3.980749e+05  ...                70565.038360
# 3         3.071484e+05  ...                93378.791060
# 4         5.243990e+05  ...                94526.402150
# 5         2.750793e+05  ...                22869.021230
# 6         2.040576e+06  ...                42814.000000
# 7         1.720015e+06  ...                39200.659430
# 8         1.587765e+06  ...                 1790.613584
# 9         5.320456e+06  ...                87521.044140
# 10        4.040093e+06  ...                48785.620480
# 11        5.874447e+06  ...                77129.954730
# 12        1.973454e+07  ...               136583.487700
# 13        2.158077e+07  ...               229287.650500
# 14        1.594478e+07  ...                94200.171560
# 15        1.516228e+07  ...                86825.617460
# 16        1.885234e+07  ...               141179.016200
# 17        1.701183e+07  ...                79667.855460
#
# [18 rows x 86 columns]

# %%
#define and run PCA
pca = PCA(n_components=2, random_state=42)
pca_data = pca.fit_transform(scaled_data)

#convert dataframe
pca_df = pd.DataFrame(data=pca_data, columns=['PC 1', 'PC 2'])


#add labels
pca_df = pd.concat([pca_df, labels], axis=1)

pca_df
# Out:
#         PC 1      PC 2     sample
# 0   1.626407  6.123725       SG_1
# 1   0.416424  5.379444       SG_2
# 2   0.603286  6.673287       SG_3
# 3  -7.718434  2.521469      GLC_1
# 4  -7.744082  3.409572      GLC_2
# 5  -7.179410  0.775556      GLC_3
# 6  -3.730115 -5.164253      PHE_1
# 7  -3.972550 -4.976868      PHE_2
# 8  -4.361938 -5.511135      PHE_3
# 9  -2.597531 -0.992549  GLC/PHE_1
# 10 -2.670153 -2.531077  GLC/PHE_2
# 11 -2.347052 -0.273132  GLC/PHE_3
# 12  6.992377 -3.498597    AMIX_1b
# 13  7.689026 -3.610943    AMIX_2b
# 14  4.975382 -3.624067    AMIX_3b
# 15  4.323288  2.851502    AMIX_1a
# 16  8.607519  1.801232    AMIX_2a
# 17  7.087556  0.646831    AMIX_3a

# %%
#plot the data
plt.scatter(pca_df['PC 1'], pca_df['PC 2'])

#add the lables

for i,txt in enumerate(labels):
    plt.annotate(txt, (pca_df['PC 1'][i], pca_df['PC 2'][i]))
    #print(i, txt)


plt.title('PCA')
# Out:
# Text(0.5, 1.0, 'PCA')

# %%
#prepare data for LDA
group_labels = [label.split('_')[0] for label in labels]

#run lda
lda = LinearDiscriminantAnalysis(n_components=2)
lda_data = lda.fit_transform(scaled_data, group_labels)

#convert to data frame
lda_df = pd.DataFrame(data=lda_data, columns=['LD 1', 'LD 2'])

#add group names
lda_df['group_label'] = group_labels

lda_df
# Out:
#         LD 1      LD 2 group_label
# 0  -0.023103 -3.150491          SG
# 1   1.083295 -1.704730          SG
# 2   1.505712 -3.014061          SG
# 3   8.247862 -1.054367         GLC
# 4   9.031182 -2.422920         GLC
# 5   6.120516  0.458189         GLC
# 6   0.505533  4.534567         PHE
# 7   0.707492  2.699511         PHE
# 8  -0.371955  3.962282         PHE
# 9  -0.003778  1.705918     GLC/PHE
# 10 -0.842151  3.104184     GLC/PHE
# 11 -1.193136  2.691975     GLC/PHE
# 12 -4.556668 -1.551455        AMIX
# 13 -4.762441 -1.254828        AMIX
# 14 -2.640047 -0.075511        AMIX
# 15 -2.981630 -0.369828        AMIX
# 16 -4.432284 -1.816327        AMIX
# 17 -5.394400 -2.742110        AMIX

# %%
#plot the data
plt.scatter(lda_df['LD 1'], lda_df['LD 2'])

#add the lables

for i,txt in enumerate(labels):
    plt.annotate(txt, (lda_df['LD 1'][i], lda_df['LD 2'][i]))
    #print(i, txt)


plt.title('LDA')
# Out:
# Text(0.5, 1.0, 'LDA')

# %%
# define and run t-SME
tsne = TSNE(n_components=2, random_state=42, perplexity=5)
tsne_data = tsne.fit_transform(scaled_data)

#convert to data frame
tsne_df = pd.DataFrame(data=tsne_data, columns=['TSNE 1', 'TSNE 2'])

#add group names
tsne_df['group_label'] = group_labels

tsne_df
# Out:
#        TSNE 1      TSNE 2 group_label
# 0  -63.502644  -14.914408          SG
# 1  -42.574898   -3.591646          SG
# 2  -57.752701   -0.730309          SG
# 3   81.740761  -28.503828         GLC
# 4   90.779083  -40.816299         GLC
# 5   72.085190  -43.911339         GLC
# 6    1.939904  -60.854977         PHE
# 7   16.117838  -72.951431         PHE
# 8   30.430450  -68.639511         PHE
# 9    8.258851  -32.084671     GLC/PHE
# 10  19.253172  -44.259171     GLC/PHE
# 11  17.276752  -18.675692     GLC/PHE
# 12 -44.733337  102.149872        AMIX
# 13 -59.197449  103.451996        AMIX
# 14 -51.382938   85.246605        AMIX
# 15 -24.284834   45.617569        AMIX
# 16 -19.666121   74.871361        AMIX
# 17 -31.388191   57.818531        AMIX

# %%
#plot the data
plt.scatter(tsne_df['TSNE 1'], tsne_df['TSNE 2'])

#add the lables

for i,txt in enumerate(labels):
    plt.annotate(txt, (tsne_df['TSNE 1'][i], tsne_df['TSNE 2'][i]))
    #print(i, txt)


plt.title('TSNE')
# Out:
# Text(0.5, 1.0, 'TSNE')
